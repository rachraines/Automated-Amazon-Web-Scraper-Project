# %%
# Import libraries
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import csv
import pandas as pd

# %%
# Connect to website
URL = 'https://www.amazon.com/Shirt-Department-got-data/dp/B07PJL8NZ3/ref=sr_1_5?dib=eyJ2IjoiMSJ9.L3OzpSkZpcBBwIs69QtAAbRgdZeM3kBLFROysLAmTIkfNP_wLmdvVdgC8YzpRxe2TqzBTWa8TaS-upgy54yu5ffv5-yz1bK7IHM-8bB0rykNDo8ynWUysxqaSvzi2ruHbjEvJy_-3IZYdb0wktb56UFS8NW_ChFnF54AXkC_bFaDbb5or2VE8D23bEUWPnzkSTquiBavnxcDj1hXtEHzP51BxysmdNOumNTWjoHpHBFlSWnwvmqNAkPkq83WOxpsWheOb9KKCCRKHzaEwDvfAqNAjZJEeBLmZMM8uQd1GUM.-kaBu-PajCX_0e4kpvBgdlGBoGQ08uKW8KUKP_j-CNg&dib_tag=se&keywords=got%2Bdata%2Btshirt&qid=1765820008&sr=8-5&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
title = soup2.find(id='productTitle').get_text()
price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()

# %%
# Clean up price and title HTML
price = price.strip()[1:6]
title = title.strip()
today = datetime.date.today()

print(title)
print(price)
print(today)
# Out:
# got data? T-Shirt
# 19.99
# 2025-12-16

# %%
# Create csv file and table headers with first line of data
# Table has been created, commented out to not overwrite in future uses
header = ['Title', 'Price', 'Date']
data = [title, price, today]

#with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    #writer = csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
# Create new dataframe using pandas
df = pd.read_csv(r'C:\Users\rfros\anaconda_projects\0a6610f9-fbfe-4f4f-9672-b6c3a1ef324f\AmazonWebScraperDataset.csv')

# %%
# Create a function that appends data to the table
def check_price():
    import datetime
    import csv
    
    URL = 'https://www.amazon.com/Shirt-Department-got-data/dp/B07PJL8NZ3/ref=sr_1_5?dib=eyJ2IjoiMSJ9.L3OzpSkZpcBBwIs69QtAAbRgdZeM3kBLFROysLAmTIkfNP_wLmdvVdgC8YzpRxe2TqzBTWa8TaS-upgy54yu5ffv5-yz1bK7IHM-8bB0rykNDo8ynWUysxqaSvzi2ruHbjEvJy_-3IZYdb0wktb56UFS8NW_ChFnF54AXkC_bFaDbb5or2VE8D23bEUWPnzkSTquiBavnxcDj1hXtEHzP51BxysmdNOumNTWjoHpHBFlSWnwvmqNAkPkq83WOxpsWheOb9KKCCRKHzaEwDvfAqNAjZJEeBLmZMM8uQd1GUM.-kaBu-PajCX_0e4kpvBgdlGBoGQ08uKW8KUKP_j-CNg&dib_tag=se&keywords=got%2Bdata%2Btshirt&qid=1765820008&sr=8-5&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    page = requests.get(URL, headers=headers)
    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
    title = soup2.find(id='productTitle').get_text()
    price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()
    price = price.strip()[1:6]
    title = title.strip()
    today = datetime.date.today()
    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
# Automate the check_price function every day
while(True):
    check_price()
    time.sleep(86400)

# %%
# Display the df
df = pd.read_csv(r'C:\Users\rfros\anaconda_projects\0a6610f9-fbfe-4f4f-9672-b6c3a1ef324f\AmazonWebScraperDataset.csv')
print(df)
